# %%
import numpy as np
import matplotlib.pyplot as plt

def generateMetricsDict(lines):
    client = {
        "loss": [],
        "accuracy": [],
        "val_loss": [],
        "val_accuracy": []
    }

    for line in lines:
        metrics = line.split("-")
        for metric in metrics:
            key, value = metric.strip().split(" ")
            client[key[:-1]].append(float(value))
    
    return client

def plot(y1, y2, y1_label, y2_label, image=None):
    x1 = np.linspace(0, 1, len(y1))
    x2 = np.linspace(0, 1, len(y2))

    plt.plot(x1, y1, '-o', label=y1_label)
    plt.plot(x2, y2, '-o', label=y2_label)

    plt.xticks([], [])

    plt.legend()

    if image != None:
        plt.savefig(image)
        
    plt.show()

# %% [markdown]
# ## Command prompt of Client 1
# ```bash
# [MODEL] After input layer
# [MODEL] After 1st hidden layer
# [MODEL] After 2nd hidden layer
# [MODEL] After 3rd hidden layer
# [MODEL] After output layer
# [MODEL] After model.compile
# (423164, 120)
# INFO flwr 2023-02-09 07:14:29,357 | app.py:135 | Starting Flower server, config: ServerConfig(num_rounds=3, round_timeout=None)
# INFO flwr 2023-02-09 07:14:29,385 | app.py:148 | Flower ECE: gRPC server running (3 rounds), SSL is disabled
# INFO flwr 2023-02-09 07:14:29,385 | server.py:86 | Initializing global parameters
# INFO flwr 2023-02-09 07:14:29,385 | server.py:270 | Requesting initial parameters from one random client
# INFO flwr 2023-02-09 07:14:33,089 | server.py:274 | Received initial parameters from one random client
# INFO flwr 2023-02-09 07:14:33,089 | server.py:88 | Evaluating initial parameters
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6919 - accuracy: 0.5220
# INFO flwr 2023-02-09 07:14:33,489 | server.py:91 | initial parameters (loss, other metrics): 0.6919019818305969, {'accuracy': 0.5220000147819519}
# INFO flwr 2023-02-09 07:14:33,489 | server.py:101 | FL starting
# DEBUG flwr 2023-02-09 07:14:39,229 | server.py:215 | fit_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-02-09 07:15:24,899 | server.py:229 | fit_round 1 received 2 results and 0 failures
# [INITIATOR] Calling aggregate_fit...
# WARNING flwr 2023-02-09 07:15:24,903 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# [INITIATOR] Saving round 1 aggregated_weights...
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4877 - accuracy: 0.7820
# INFO flwr 2023-02-09 07:15:24,991 | server.py:116 | fit progress: (1, 0.4876748323440552, {'accuracy': 0.7820000052452087}, 51.5009218)
# DEBUG flwr 2023-02-09 07:15:24,991 | server.py:165 | evaluate_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-02-09 07:15:25,555 | server.py:179 | evaluate_round 1 received 2 results and 0 failures
# WARNING flwr 2023-02-09 07:15:25,555 | fedavg.py:273 | No evaluate_metrics_aggregation_fn provided
# DEBUG flwr 2023-02-09 07:15:25,555 | server.py:215 | fit_round 2: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-02-09 07:16:10,957 | server.py:229 | fit_round 2 received 2 results and 0 failures
# [INITIATOR] Calling aggregate_fit...
# [INITIATOR] Saving round 2 aggregated_weights...
# 16/16 [==============================] - 0s 867us/step - loss: 0.4862 - accuracy: 0.7860
# INFO flwr 2023-02-09 07:16:11,039 | server.py:116 | fit progress: (2, 0.48624423146247864, {'accuracy': 0.7860000133514404}, 97.5493301)
# DEBUG flwr 2023-02-09 07:16:11,039 | server.py:165 | evaluate_round 2: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-02-09 07:16:11,602 | server.py:179 | evaluate_round 2 received 2 results and 0 failures
# DEBUG flwr 2023-02-09 07:16:11,602 | server.py:215 | fit_round 3: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-02-09 07:16:56,626 | server.py:229 | fit_round 3 received 2 results and 0 failures
# [INITIATOR] Calling aggregate_fit...
# [INITIATOR] Saving round 3 aggregated_weights...
# 16/16 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.7940
# INFO flwr 2023-02-09 07:16:56,715 | server.py:116 | fit progress: (3, 0.4844627380371094, {'accuracy': 0.7940000295639038}, 143.2246309)
# DEBUG flwr 2023-02-09 07:16:56,715 | server.py:165 | evaluate_round 3: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-02-09 07:16:57,278 | server.py:179 | evaluate_round 3 received 2 results and 0 failures
# INFO flwr 2023-02-09 07:16:57,278 | server.py:144 | FL finished in 143.7877691
# INFO flwr 2023-02-09 07:16:57,278 | app.py:198 | app_fit: losses_distributed [(1, 0.45349612832069397), (2, 0.4497712552547455), (3, 0.4508616328239441)]
# INFO flwr 2023-02-09 07:16:57,278 | app.py:199 | app_fit: metrics_distributed {}
# INFO flwr 2023-02-09 07:16:57,278 | app.py:200 | app_fit: losses_centralized [(0, 0.6919019818305969), (1, 0.4876748323440552), (2, 0.48624423146247864), (3, 0.4844627380371094)]
# INFO flwr 2023-02-09 07:16:57,278 | app.py:201 | app_fit: metrics_centralized {'accuracy': [(0, 0.5220000147819519), (1, 0.7820000052452087), (2, 0.7860000133514404), (3, 0.7940000295639038)]}
# ```

# %%
client1_val_accuracy = [0.5220, 0.7820, 0.7860, 0.7940]

# %%
y1 = client1_val_accuracy

x1 = np.linspace(0, 1, len(client1_val_accuracy))

plt.plot(x1, y1, '-o', label='Server side validation accuracy')

plt.xticks([], [])
plt.legend()

plt.savefig('client1.png')
plt.show()

# %% [markdown]
# ## Command prompt of Client 2
#
# ```bash
# [MODEL] After input layer
# [MODEL] After 1st hidden layer
# [MODEL] After 2nd hidden layer
# [MODEL] After 3rd hidden layer
# [MODEL] After output layer
# [MODEL] After model.compile
# (423164, 120)
# 117
# INFO flwr 2023-02-09 07:14:33,058 | grpc.py:50 | Opened insecure gRPC connection (no certificates were passed)
# DEBUG flwr 2023-02-09 07:14:33,062 | connection.py:38 | ChannelConnectivity.IDLE
# DEBUG flwr 2023-02-09 07:14:33,075 | connection.py:38 | ChannelConnectivity.CONNECTING
# DEBUG flwr 2023-02-09 07:14:33,076 | connection.py:38 | ChannelConnectivity.READY
# [CLIENT] Calling get_parameters...
# [CLIENT] Calling fit...
# [CLIENT] fit: After setting weights
# [CLIENT] fit: Before model.fit
# Epoch 1/5
# 6282/6282 [==============================] - 10s 1ms/step - loss: 0.4636 - accuracy: 0.8002 - val_loss: 0.4511 - val_accuracy: 0.8061
# Epoch 2/5
# 6282/6282 [==============================] - 8s 1ms/step - loss: 0.4582 - accuracy: 0.8007 - val_loss: 0.4508 - val_accuracy: 0.8049
# Epoch 3/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4567 - accuracy: 0.8008 - val_loss: 0.4505 - val_accuracy: 0.8064
# Epoch 4/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4558 - accuracy: 0.8010 - val_loss: 0.4502 - val_accuracy: 0.8075
# Epoch 5/5
# 6282/6282 [==============================] - 10s 2ms/step - loss: 0.4551 - accuracy: 0.8012 - val_loss: 0.4498 - val_accuracy: 0.8064
# [CLIENT] fit: After model.fit
# [CLIENT] fit: Fit history (accuracy) in client: [0.8001567125320435, 0.8006716370582581, 0.8007512092590332, 0.8009750843048096, 0.8012462258338928]
# [CLIENT] fit: Results: {'loss': 0.4636389911174774, 'accuracy': 0.8001567125320435, 'val_loss': 0.4511241912841797, 'val_accuracy': 0.8061345219612122}
# [CLIENT] fit: Eval accuracy: 0.8045749068260193
# [CLIENT] Calling fit...
# [CLIENT] fit: After setting weights
# [CLIENT] fit: Before model.fit
# Epoch 1/5
# 6282/6282 [==============================] - 10s 2ms/step - loss: 0.4553 - accuracy: 0.8010 - val_loss: 0.4498 - val_accuracy: 0.8067
# Epoch 2/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4543 - accuracy: 0.8012 - val_loss: 0.4503 - val_accuracy: 0.8067
# Epoch 3/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4538 - accuracy: 0.8015 - val_loss: 0.4507 - val_accuracy: 0.8066
# Epoch 4/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4532 - accuracy: 0.8016 - val_loss: 0.4497 - val_accuracy: 0.8067
# Epoch 5/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4528 - accuracy: 0.8016 - val_loss: 0.4499 - val_accuracy: 0.8061
# [CLIENT] fit: After model.fit
# [CLIENT] fit: Fit history (accuracy) in client: [0.8010223507881165, 0.8011840581893921, 0.8014800548553467, 0.8015919923782349, 0.8016119003295898]
# [CLIENT] fit: Results: {'loss': 0.45525744557380676, 'accuracy': 0.8010223507881165, 'val_loss': 0.44979000091552734, 'val_accuracy': 0.8066543936729431}
# [CLIENT] fit: Eval accuracy: 0.8068906664848328
# [CLIENT] Calling fit...
# [CLIENT] fit: After setting weights
# [CLIENT] fit: Before model.fit
# Epoch 1/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4523 - accuracy: 0.8021 - val_loss: 0.4498 - val_accuracy: 0.8068
# Epoch 2/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4520 - accuracy: 0.8020 - val_loss: 0.4502 - val_accuracy: 0.8062
# Epoch 3/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4516 - accuracy: 0.8022 - val_loss: 0.4505 - val_accuracy: 0.8067
# Epoch 4/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4512 - accuracy: 0.8022 - val_loss: 0.4502 - val_accuracy: 0.8067
# Epoch 5/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4510 - accuracy: 0.8026 - val_loss: 0.4509 - val_accuracy: 0.8068
# [CLIENT] fit: After model.fit
# [CLIENT] fit: Fit history (accuracy) in client: [0.8020795583724976, 0.8019974827766418, 0.802169144153595, 0.8022313117980957, 0.8025571703910828]
# [CLIENT] fit: Results: {'loss': 0.4522725045681, 'accuracy': 0.8020795583724976, 'val_loss': 0.4497586488723755, 'val_accuracy': 0.8068434000015259}
# [CLIENT] fit: Eval accuracy: 0.8070797324180603
# DEBUG flwr 2023-02-09 07:16:57,285 | connection.py:109 | gRPC channel closed
# INFO flwr 2023-02-09 07:16:57,285 | app.py:152 | Disconnect and shut down
# ```

# %%
lines = [
    "loss: 0.4636 - accuracy: 0.8002 - val_loss: 0.4511 - val_accuracy: 0.8061",
    "loss: 0.4582 - accuracy: 0.8007 - val_loss: 0.4508 - val_accuracy: 0.8049",
    "loss: 0.4567 - accuracy: 0.8008 - val_loss: 0.4505 - val_accuracy: 0.8064",
    "loss: 0.4558 - accuracy: 0.8010 - val_loss: 0.4502 - val_accuracy: 0.8075",
    "loss: 0.4551 - accuracy: 0.8012 - val_loss: 0.4498 - val_accuracy: 0.8064",
    "loss: 0.4553 - accuracy: 0.8010 - val_loss: 0.4498 - val_accuracy: 0.8067",
    "loss: 0.4543 - accuracy: 0.8012 - val_loss: 0.4503 - val_accuracy: 0.8067",
    "loss: 0.4538 - accuracy: 0.8015 - val_loss: 0.4507 - val_accuracy: 0.8066",
    "loss: 0.4532 - accuracy: 0.8016 - val_loss: 0.4497 - val_accuracy: 0.8067",
    "loss: 0.4528 - accuracy: 0.8016 - val_loss: 0.4499 - val_accuracy: 0.8061",
    "loss: 0.4523 - accuracy: 0.8021 - val_loss: 0.4498 - val_accuracy: 0.8068",
    "loss: 0.4520 - accuracy: 0.8020 - val_loss: 0.4502 - val_accuracy: 0.8062",
    "loss: 0.4516 - accuracy: 0.8022 - val_loss: 0.4505 - val_accuracy: 0.8067",
    "loss: 0.4512 - accuracy: 0.8022 - val_loss: 0.4502 - val_accuracy: 0.8067",
    "loss: 0.4510 - accuracy: 0.8026 - val_loss: 0.4509 - val_accuracy: 0.8068"
]

client2 = generateMetricsDict(lines)

# %%
plot(client2["accuracy"], client2["val_accuracy"], "Training Accuracy", "Validation Accuracy")

# %%
plot(client2["loss"][:-1], client2["val_loss"][:-1], "Training Loss", "Validation Loss", 'client2.png')

# %% [markdown]
# ## Command prompt of Client 3
#
# ```bash
# [MODEL] After input layer
# [MODEL] After 1st hidden layer
# [MODEL] After 2nd hidden layer
# [MODEL] After 3rd hidden layer
# [MODEL] After output layer
# [MODEL] After model.compile
# (423164, 120)
# 117
# INFO flwr 2023-02-09 07:14:39,222 | grpc.py:50 | Opened insecure gRPC connection (no certificates were passed)
# DEBUG flwr 2023-02-09 07:14:39,227 | connection.py:38 | ChannelConnectivity.IDLE
# DEBUG flwr 2023-02-09 07:14:39,227 | connection.py:38 | ChannelConnectivity.CONNECTING
# DEBUG flwr 2023-02-09 07:14:39,228 | connection.py:38 | ChannelConnectivity.READY
# [CLIENT] Calling fit...
# [CLIENT] fit: After setting weights
# [CLIENT] fit: Before model.fit
# Epoch 1/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4637 - accuracy: 0.8004 - val_loss: 0.4517 - val_accuracy: 0.8063
# Epoch 2/5
# 6282/6282 [==============================] - 8s 1ms/step - loss: 0.4581 - accuracy: 0.8008 - val_loss: 0.4509 - val_accuracy: 0.8066
# Epoch 3/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4565 - accuracy: 0.8010 - val_loss: 0.4505 - val_accuracy: 0.8066
# Epoch 4/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4555 - accuracy: 0.8010 - val_loss: 0.4498 - val_accuracy: 0.8059
# Epoch 5/5
# 6282/6282 [==============================] - 10s 2ms/step - loss: 0.4549 - accuracy: 0.8012 - val_loss: 0.4510 - val_accuracy: 0.8061
# [CLIENT] fit: After model.fit
# [CLIENT] fit: Fit history (accuracy) in client: [0.8003930449485779, 0.8007910251617432, 0.8009875416755676, 0.8009800910949707, 0.8012363314628601]
# [CLIENT] fit: Results: {'loss': 0.4637455642223358, 'accuracy': 0.8003930449485779, 'val_loss': 0.45172011852264404, 'val_accuracy': 0.806276261806488}
# [CLIENT] fit: Eval accuracy: 0.8045749068260193
# [CLIENT] Calling fit...
# [CLIENT] fit: After setting weights
# [CLIENT] fit: Before model.fit
# Epoch 1/5
# 6282/6282 [==============================] - 10s 2ms/step - loss: 0.4552 - accuracy: 0.8011 - val_loss: 0.4501 - val_accuracy: 0.8063
# Epoch 2/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4543 - accuracy: 0.8015 - val_loss: 0.4502 - val_accuracy: 0.8067
# Epoch 3/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4538 - accuracy: 0.8015 - val_loss: 0.4504 - val_accuracy: 0.8060
# Epoch 4/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4531 - accuracy: 0.8015 - val_loss: 0.4508 - val_accuracy: 0.8057
# Epoch 5/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4529 - accuracy: 0.8018 - val_loss: 0.4505 - val_accuracy: 0.8076
# [CLIENT] fit: After model.fit
# [CLIENT] fit: Fit history (accuracy) in client: [0.8011218905448914, 0.8014875650405884, 0.8014676570892334, 0.8015348315238953, 0.8017661571502686]
# [CLIENT] fit: Results: {'loss': 0.4551984369754791, 'accuracy': 0.8011218905448914, 'val_loss': 0.45005178451538086, 'val_accuracy': 0.8063235282897949}
# [CLIENT] fit: Eval accuracy: 0.8068906664848328
# [CLIENT] Calling fit...
# [CLIENT] fit: After setting weights
# [CLIENT] fit: Before model.fit
# Epoch 1/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4524 - accuracy: 0.8018 - val_loss: 0.4507 - val_accuracy: 0.8066
# Epoch 2/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4520 - accuracy: 0.8019 - val_loss: 0.4504 - val_accuracy: 0.8063
# Epoch 3/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4518 - accuracy: 0.8020 - val_loss: 0.4505 - val_accuracy: 0.8056
# Epoch 4/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4513 - accuracy: 0.8023 - val_loss: 0.4505 - val_accuracy: 0.8063
# Epoch 5/5
# 6282/6282 [==============================] - 9s 1ms/step - loss: 0.4511 - accuracy: 0.8021 - val_loss: 0.4510 - val_accuracy: 0.8065
# [CLIENT] fit: After model.fit
# [CLIENT] fit: Fit history (accuracy) in client: [0.8018134236335754, 0.80193030834198, 0.8019875288009644, 0.8022910356521606, 0.8021442294120789]
# [CLIENT] fit: Results: {'loss': 0.45240792632102966, 'accuracy': 0.8018134236335754, 'val_loss': 0.4506908059120178, 'val_accuracy': 0.8066071271896362}
# [CLIENT] fit: Eval accuracy: 0.8070797324180603
# DEBUG flwr 2023-02-09 07:16:57,285 | connection.py:109 | gRPC channel close
# ```

# %%
lines = [
    "loss: 0.4637 - accuracy: 0.8004 - val_loss: 0.4517 - val_accuracy: 0.8063",
    "loss: 0.4581 - accuracy: 0.8008 - val_loss: 0.4509 - val_accuracy: 0.8066",
    "loss: 0.4565 - accuracy: 0.8010 - val_loss: 0.4505 - val_accuracy: 0.8066",
    "loss: 0.4555 - accuracy: 0.8010 - val_loss: 0.4498 - val_accuracy: 0.8059",
    "loss: 0.4549 - accuracy: 0.8012 - val_loss: 0.4510 - val_accuracy: 0.8061",
    "loss: 0.4552 - accuracy: 0.8011 - val_loss: 0.4501 - val_accuracy: 0.8063",
    "loss: 0.4543 - accuracy: 0.8015 - val_loss: 0.4502 - val_accuracy: 0.8067",
    "loss: 0.4538 - accuracy: 0.8015 - val_loss: 0.4504 - val_accuracy: 0.8060",
    "loss: 0.4531 - accuracy: 0.8015 - val_loss: 0.4508 - val_accuracy: 0.8057",
    "loss: 0.4529 - accuracy: 0.8018 - val_loss: 0.4505 - val_accuracy: 0.8076",
    "loss: 0.4524 - accuracy: 0.8018 - val_loss: 0.4507 - val_accuracy: 0.8066",
    "loss: 0.4520 - accuracy: 0.8019 - val_loss: 0.4504 - val_accuracy: 0.8063",
    "loss: 0.4518 - accuracy: 0.8020 - val_loss: 0.4505 - val_accuracy: 0.8056",
    "loss: 0.4513 - accuracy: 0.8023 - val_loss: 0.4505 - val_accuracy: 0.8063",
    "loss: 0.4511 - accuracy: 0.8021 - val_loss: 0.4510 - val_accuracy: 0.8065"
]

client3 = generateMetricsDict(lines)

# %%
plot(client3["accuracy"], client3["val_accuracy"], "Training Accuracy", "Validation Accuracy")

# %%
plot(client3["loss"][:-1], client3["val_loss"][:-1], "Training Loss", "Validation Loss", 'client3.png')
